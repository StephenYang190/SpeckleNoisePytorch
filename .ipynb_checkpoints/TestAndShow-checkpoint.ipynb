# %%
# !python main.py --mode test --model checkpoints/demo_cm/demo-08/epoch_40.pth
# Out:
# 2020-12-14 16:58:05.941153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2020-12-14 16:58:05.952894: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# SNRNetwork
# SNRc(
#   (convs): ModuleList(
#     (0): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (1): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (2): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (3): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (4): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (5): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (6): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (7): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (8): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (9): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (10): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (11): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (12): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (13): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (14): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#     (15): Conv_BN_ACT(
#       (conv): Conv_BN(
#         (conv): VenConv(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): PReLU(num_parameters=1)
#     )
#   )
#   (rescons): ModuleList(
#     (0): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (1): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (2): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (3): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (4): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (5): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (6): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (7): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (8): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (9): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (10): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (11): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (12): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (13): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (14): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (15): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): Conv_BN(
#           (conv): VenConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act): PReLU(num_parameters=1)
#       )
#     )
#   )
#   (proin): Conv_BN_ACT(
#     (conv): Conv_BN(
#       (conv): VenConv(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act): PReLU(num_parameters=1)
#   )
#   (prout1): Conv_BN_ACT(
#     (conv): Conv_BN(
#       (conv): VenConv(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act): PReLU(num_parameters=1)
#   )
#   (prout2): Conv_BN_ACT(
#     (conv): Conv_BN(
#       (conv): VenConv(
#         (conv): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act): PReLU(num_parameters=1)
#   )
# )
# The number of parameters: 1815093
# Loading pre-trained model from checkpoints/demo_cm/demo-08/epoch_80.pth...
# Proccess :53631.png
# Proccess :B_cell_1.png
# Proccess :breast.png
# Proccess :36209.png
# Proccess :a.png
# Proccess :b.png
# Proccess :leiomy_1.png
# Proccess :1.png
# Proccess :leiomy_2.png
# Proccess :B_cell_2.png
# Speed: 9.546899 FPS
# Test Done!

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
import os

# %%
dataPath = './test/demo-18/'
files = os.listdir(dataPath)

for file in files:
    if file.endswith(".png" or ".jpg"):

        noiseImg = dataPath + file
        noiseImg = cv2.imread(noiseImg)

        high, weight, _ = noiseImg.shape

        noiseImg = np.asarray(noiseImg / 255.0, np.float)

        plt.figure()
        plt.title(file)
        plt.imshow(noiseImg, cmap='gray')
        plt.show()
