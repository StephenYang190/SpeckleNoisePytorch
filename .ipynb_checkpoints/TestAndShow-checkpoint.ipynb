# %%
# !python main.py --mode test --op om --model omcheck/demo-07/epoch_40.pth --device_id cuda:0
# Out:
# 2021-01-06 21:19:51.972388: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer.so.6
# 2021-01-06 21:19:51.974045: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libnvinfer_plugin.so.6
# SNRNetwork
# SNRom(
#   (octavecons): ModuleList(
#     (0): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (1): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (2): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (3): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (4): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (5): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (6): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (7): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (8): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (9): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (10): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (11): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (12): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (13): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (14): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#     (15): Conv_BN_ACT(
#       (conv): OctaveConv(
#         (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act): PReLU(num_parameters=1)
#     )
#   )
#   (rescons): ModuleList(
#     (0): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (1): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (2): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (3): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (4): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (5): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (6): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (7): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (8): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (9): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (10): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (11): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (12): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (13): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (14): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#     (15): ResBlock(
#       (conv1): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#       (conv2): Conv_BN_ACT(
#         (conv): OctaveConv(
#           (downsample): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#           (upsample): Upsample(scale_factor=2.0, mode=nearest)
#           (conv_l2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_l2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2l): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (conv_h2h): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (bn_h): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (bn_l): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): PReLU(num_parameters=1)
#       )
#     )
#   )
#   (downs): AvgPool2d(kernel_size=(2, 2), stride=2, padding=0)
#   (proninl): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (proninh): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (actli): PReLU(num_parameters=1)
#   (acthi): PReLU(num_parameters=1)
#   (prouth): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (acth): ReLU()
#   (proutc): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (actc): ReLU()
# )
# The number of parameters: 1776539
# Loading pre-trained model from omcheck/demo-06/epoch_80.pth...
# Proccess :53631.png
# Proccess :B_cell_1.png
# Proccess :breast.png
# Proccess :36209.png
# Proccess :a.png
# Proccess :b.png
# Proccess :leiomy_1.png
# Proccess :1.png
# Proccess :leiomy_2.png
# Proccess :B_cell_2.png
# Speed: 2.218013 FPS
# Test Done!

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
import os

# %%
dataPath = './test/demo-18/'
files = os.listdir(dataPath)

for file in files:
    if file.endswith(".png" or ".jpg"):

        noiseImg = dataPath + file
        noiseImg = cv2.imread(noiseImg)

        high, weight, _ = noiseImg.shape

        noiseImg = np.asarray(noiseImg / 255.0, np.float)

        plt.figure()
        plt.title(file)
        plt.imshow(noiseImg, cmap='gray')
        plt.show()
